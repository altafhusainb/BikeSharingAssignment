# %% [markdown]
#  ## Bike Sharing Assignment Using Multiple Linear Regression

# %% [markdown]
# ## Problem Statement
# A US bike-sharing provider BoomBikes has recently suffered considerable dips in their revenues due to the ongoing Corona pandemic. The company is finding it very difficult to sustain in the current market scenario. So, it has decided to come up with a mindful business plan to be able to accelerate its revenue as soon as the ongoing lockdown comes to an end, and the economy restores to a healthy state.
#
# The company wants to know:
#
# Which variables are significant in predicting the demand for shared bikes.
# How well those variables describe the bike demands
# Based on various meteorological surveys and people's styles, the service provider firm has gathered a large dataset on daily bike demands across the American market based on some factors.
#
#
# ## Business Goal:
#
# You are required to model the demand for shared bikes with the available independent variables. It will be used by the management to understand how exactly the demands vary with different features. They can accordingly manipulate the business strategy to meet the demand levels and meet the customer's expectations. Further, the model will be a good way for management to understand the demand dynamics of a new market.

# %%
## Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
bike = pd.DataFrame(pd.read_csv("day.csv"))

# %%
# Check the head of the dataset
bike.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018       1   0     1        0        6           0
# 1        2  02-01-2018       1   0     1        0        0           0
# 2        3  03-01-2018       1   0     1        0        1           1
# 3        4  04-01-2018       1   0     1        0        2           1
# 4        5  05-01-2018       1   0     1        0        3           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
# Check the descriptive information
bike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.4+ KB

# %%
bike.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean   365.500000    2.498630    0.500000    6.526027    0.028767    2.997260
# std    210.877136    1.110184    0.500343    3.450215    0.167266    2.006161
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.250000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    365.500000    3.000000    0.500000    7.000000    0.000000    3.000000
# 75%    547.750000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    730.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     0.683562    1.394521   20.319259   23.726322   62.765175   12.763620
# std      0.465405    0.544807    7.506729    8.150308   14.237589    5.195841
# min      0.000000    1.000000    2.424346    3.953480    0.000000    1.500244
# 25%      0.000000    1.000000   13.811885   16.889713   52.000000    9.041650
# 50%      1.000000    1.000000   20.465826   24.368225   62.625000   12.125325
# 75%      1.000000    2.000000   26.880615   30.445775   72.989575   15.625589
# max      1.000000    3.000000   35.328347   42.044800   97.250000   34.000021
#
#             casual   registered          cnt
# count   730.000000   730.000000   730.000000
# mean    849.249315  3658.757534  4508.006849
# std     686.479875  1559.758728  1936.011647
# min       2.000000    20.000000    22.000000
# 25%     316.250000  2502.250000  3169.750000
# 50%     717.000000  3664.500000  4548.500000
# 75%    1096.500000  4783.250000  5966.000000
# max    3410.000000  6946.000000  8714.000000

# %%
# Check the shape of df

print(bike.shape)
# Out:
# (730, 16)

# %% [markdown]
# Validated numm or missing values

# %%
# percentage of missing values in each column
round(100*(bike.isnull().sum()/len(bike)), 2).sort_values(ascending=False)
# Out:
# instant       0.0
# dteday        0.0
# season        0.0
# yr            0.0
# mnth          0.0
# holiday       0.0
# weekday       0.0
# workingday    0.0
# weathersit    0.0
# temp          0.0
# atemp         0.0
# hum           0.0
# windspeed     0.0
# casual        0.0
# registered    0.0
# cnt           0.0
# dtype: float64

# %%
# row-wise null count percentage
round((bike.isnull().sum(axis=1)/len(bike))*100,2).sort_values(ascending=False)
# Out:
# 0      0.0
# 479    0.0
# 481    0.0
# 482    0.0
# 483    0.0
#       ...
# 245    0.0
# 246    0.0
# 247    0.0
# 248    0.0
# 729    0.0
# Length: 730, dtype: float64

# %% [markdown]
#  **Validated duplcicate values**

# %%
bike_dup = bike.copy()

# Checking for duplicates and dropping the entire duplicate row if any
bike_dup.drop_duplicates(subset=None, inplace=True)

# %%
bike_dup.shape
# Out:
# (730, 16)

# %%
bike.shape
# Out:
# (730, 16)

# %% [markdown]
# **Data Cleaning**

# %%
#Create a copy of the  dataframe, without the 'instant' column,

#as this will have unique values, and donot make sense to do a value count on it.

bike_dummy=bike.iloc[:,1:16]

# %%
for col in bike_dummy:
    print(bike_dummy[col].value_counts(ascending=False), '\n\n\n')
# Out:
# dteday
# 01-01-2018    1
# 25-04-2019    1
# 27-04-2019    1
# 28-04-2019    1
# 29-04-2019    1
#              ..
# 03-09-2018    1
# 04-09-2018    1
# 05-09-2018    1
# 06-09-2018    1
# 31-12-2019    1
# Name: count, Length: 730, dtype: int64
#
#
#
# season
# 3    188
# 2    184
# 1    180
# 4    178
# Name: count, dtype: int64
#
#
#
# yr
# 0    365
# 1    365
# Name: count, dtype: int64
#
#
#
# mnth
# 1     62
# 3     62
# 5     62
# 7     62
# 8     62
# 10    62
# 12    62
# 4     60
# 6     60
# 9     60
# 11    60
# 2     56
# Name: count, dtype: int64
#
#
#
# holiday
# 0    709
# 1     21
# Name: count, dtype: int64
#
#
#
# weekday
# 6    105
# 0    105
# 1    105
# 2    104
# 4    104
# 5    104
# 3    103
# Name: count, dtype: int64
#
#
#
# workingday
# 1    499
# 0    231
# Name: count, dtype: int64
#
#
#
# weathersit
# 1    463
# 2    246
# 3     21
# Name: count, dtype: int64
#
#
#
# temp
# 26.035000    5
# 10.899153    5
# 27.880000    4
# 28.563347    4
# 23.130847    4
#             ..
# 27.435847    1
# 26.376653    1
# 28.989419    1
# 28.700000    1
# 8.849153     1
# Name: count, Length: 498, dtype: int64
#
#
#
# atemp
# 32.73440    4
# 18.78105    3
# 31.85040    3
# 28.59875    2
# 23.32625    2
#            ..
# 28.94730    1
# 30.46145    1
# 30.10650    1
# 31.34500    1
# 11.17435    1
# Name: count, Length: 689, dtype: int64
#
#
#
# hum
# 61.3333    4
# 63.0833    3
# 55.2083    3
# 60.5000    3
# 56.8333    3
#           ..
# 54.8333    1
# 56.1765    1
# 85.0000    1
# 76.1250    1
# 57.7500    1
# Name: count, Length: 594, dtype: int64
#
#
#
# windspeed
# 9.041918     3
# 11.166689    3
# 11.250104    3
# 15.333486    3
# 7.959064     3
#             ..
# 12.416775    1
# 13.833289    1
# 14.250632    1
# 23.044181    1
# 10.374682    1
# Name: count, Length: 649, dtype: int64
#
#
#
# casual
# 120     4
# 968     4
# 639     3
# 163     3
# 775     3
#        ..
# 2521    1
# 1935    1
# 783     1
# 688     1
# 364     1
# Name: count, Length: 605, dtype: int64
#
#
#
# registered
# 4841    3
# 6248    3
# 1707    3
# 3461    2
# 2713    2
#        ..
# 4138    1
# 3231    1
# 4018    1
# 3077    1
# 2290    1
# Name: count, Length: 678, dtype: int64
#
#
#
# cnt
# 5409    2
# 2424    2
# 5698    2
# 4459    2
# 5119    2
#        ..
# 5345    1
# 5046    1
# 4713    1
# 4763    1
# 2729    1
# Name: count, Length: 695, dtype: int64

# %%
bike.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %% [markdown]
# Removing the columns which are not required Viz Casual,registered and instant

# %%
bike_new=bike[['season', 'yr', 'mnth', 'holiday', 'weekday',
       'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
       'cnt']]

# %%
bike_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      730 non-null    int64
#  1   yr          730 non-null    int64
#  2   mnth        730 non-null    int64
#  3   holiday     730 non-null    int64
#  4   weekday     730 non-null    int64
#  5   workingday  730 non-null    int64
#  6   weathersit  730 non-null    int64
#  7   temp        730 non-null    float64
#  8   atemp       730 non-null    float64
#  9   hum         730 non-null    float64
#  10  windspeed   730 non-null    float64
#  11  cnt         730 non-null    int64
# dtypes: float64(4), int64(8)
# memory usage: 68.6 KB

# %% [markdown]
# #### Creating Dummy Variables

# %%
# Check the datatypes before convertion
bike_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      730 non-null    int64
#  1   yr          730 non-null    int64
#  2   mnth        730 non-null    int64
#  3   holiday     730 non-null    int64
#  4   weekday     730 non-null    int64
#  5   workingday  730 non-null    int64
#  6   weathersit  730 non-null    int64
#  7   temp        730 non-null    float64
#  8   atemp       730 non-null    float64
#  9   hum         730 non-null    float64
#  10  windspeed   730 non-null    float64
#  11  cnt         730 non-null    int64
# dtypes: float64(4), int64(8)
# memory usage: 68.6 KB

# %%
# Convert to 'category' data type

bike_new['season']=bike_new['season'].astype('category')
bike_new['weathersit']=bike_new['weathersit'].astype('category')
bike_new['mnth']=bike_new['mnth'].astype('category')
bike_new['weekday']=bike_new['weekday'].astype('category')

# %%
bike_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      730 non-null    category
#  1   yr          730 non-null    int64
#  2   mnth        730 non-null    category
#  3   holiday     730 non-null    int64
#  4   weekday     730 non-null    category
#  5   workingday  730 non-null    int64
#  6   weathersit  730 non-null    category
#  7   temp        730 non-null    float64
#  8   atemp       730 non-null    float64
#  9   hum         730 non-null    float64
#  10  windspeed   730 non-null    float64
#  11  cnt         730 non-null    int64
# dtypes: category(4), float64(4), int64(4)
# memory usage: 49.7 KB

# %%
# This code does 3 things:
# 1) Create Dummy variable
# 2) Drop original variable for which the dummy was created
# 3) Drop first dummy variable for each set of dummies created.

bike_new = pd.get_dummies(bike_new, drop_first=True)
# Convert the boolean True/False to 1/0 for all the newly created dummy columns
bike_new = bike_new.astype(int)
# Check the resulting dataframe
bike_new.head()
bike_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 30 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   yr            730 non-null    int64
#  1   holiday       730 non-null    int64
#  2   workingday    730 non-null    int64
#  3   temp          730 non-null    int64
#  4   atemp         730 non-null    int64
#  5   hum           730 non-null    int64
#  6   windspeed     730 non-null    int64
#  7   cnt           730 non-null    int64
#  8   season_2      730 non-null    int64
#  9   season_3      730 non-null    int64
#  10  season_4      730 non-null    int64
#  11  mnth_2        730 non-null    int64
#  12  mnth_3        730 non-null    int64
#  13  mnth_4        730 non-null    int64
#  14  mnth_5        730 non-null    int64
#  15  mnth_6        730 non-null    int64
#  16  mnth_7        730 non-null    int64
#  17  mnth_8        730 non-null    int64
#  18  mnth_9        730 non-null    int64
#  19  mnth_10       730 non-null    int64
#  20  mnth_11       730 non-null    int64
#  21  mnth_12       730 non-null    int64
#  22  weekday_1     730 non-null    int64
#  23  weekday_2     730 non-null    int64
#  24  weekday_3     730 non-null    int64
#  25  weekday_4     730 non-null    int64
#  26  weekday_5     730 non-null    int64
#  27  weekday_6     730 non-null    int64
#  28  weathersit_2  730 non-null    int64
#  29  weathersit_3  730 non-null    int64
# dtypes: int64(30)
# memory usage: 171.2 KB

# %%
bike_new.shape
# Out:
# (730, 30)

# %% [markdown]
# Data Splitting

# %%
# Check the shape before spliting

bike_new.shape
# Out:
# (730, 30)

# %%
# Check the info before spliting

bike_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 30 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   yr            730 non-null    int64
#  1   holiday       730 non-null    int64
#  2   workingday    730 non-null    int64
#  3   temp          730 non-null    int64
#  4   atemp         730 non-null    int64
#  5   hum           730 non-null    int64
#  6   windspeed     730 non-null    int64
#  7   cnt           730 non-null    int64
#  8   season_2      730 non-null    int64
#  9   season_3      730 non-null    int64
#  10  season_4      730 non-null    int64
#  11  mnth_2        730 non-null    int64
#  12  mnth_3        730 non-null    int64
#  13  mnth_4        730 non-null    int64
#  14  mnth_5        730 non-null    int64
#  15  mnth_6        730 non-null    int64
#  16  mnth_7        730 non-null    int64
#  17  mnth_8        730 non-null    int64
#  18  mnth_9        730 non-null    int64
#  19  mnth_10       730 non-null    int64
#  20  mnth_11       730 non-null    int64
#  21  mnth_12       730 non-null    int64
#  22  weekday_1     730 non-null    int64
#  23  weekday_2     730 non-null    int64
#  24  weekday_3     730 non-null    int64
#  25  weekday_4     730 non-null    int64
#  26  weekday_5     730 non-null    int64
#  27  weekday_6     730 non-null    int64
#  28  weathersit_2  730 non-null    int64
#  29  weathersit_3  730 non-null    int64
# dtypes: int64(30)
# memory usage: 171.2 KB

# %%
from sklearn.model_selection import train_test_split

# We should specify 'random_state' so that the train and test data set always have the same rows, respectively

np.random.seed(0)
df_train, df_test = train_test_split(bike_new, train_size = 0.70, test_size = 0.30, random_state = 333)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 510 entries, 483 to 366
# Data columns (total 30 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   yr            510 non-null    int64
#  1   holiday       510 non-null    int64
#  2   workingday    510 non-null    int64
#  3   temp          510 non-null    int64
#  4   atemp         510 non-null    int64
#  5   hum           510 non-null    int64
#  6   windspeed     510 non-null    int64
#  7   cnt           510 non-null    int64
#  8   season_2      510 non-null    int64
#  9   season_3      510 non-null    int64
#  10  season_4      510 non-null    int64
#  11  mnth_2        510 non-null    int64
#  12  mnth_3        510 non-null    int64
#  13  mnth_4        510 non-null    int64
#  14  mnth_5        510 non-null    int64
#  15  mnth_6        510 non-null    int64
#  16  mnth_7        510 non-null    int64
#  17  mnth_8        510 non-null    int64
#  18  mnth_9        510 non-null    int64
#  19  mnth_10       510 non-null    int64
#  20  mnth_11       510 non-null    int64
#  21  mnth_12       510 non-null    int64
#  22  weekday_1     510 non-null    int64
#  23  weekday_2     510 non-null    int64
#  24  weekday_3     510 non-null    int64
#  25  weekday_4     510 non-null    int64
#  26  weekday_5     510 non-null    int64
#  27  weekday_6     510 non-null    int64
#  28  weathersit_2  510 non-null    int64
#  29  weathersit_3  510 non-null    int64
# dtypes: int64(30)
# memory usage: 123.5 KB

# %%
df_train.shape
# Out:
# (510, 30)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 219 entries, 22 to 313
# Data columns (total 30 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   yr            219 non-null    int64
#  1   holiday       219 non-null    int64
#  2   workingday    219 non-null    int64
#  3   temp          219 non-null    int64
#  4   atemp         219 non-null    int64
#  5   hum           219 non-null    int64
#  6   windspeed     219 non-null    int64
#  7   cnt           219 non-null    int64
#  8   season_2      219 non-null    int64
#  9   season_3      219 non-null    int64
#  10  season_4      219 non-null    int64
#  11  mnth_2        219 non-null    int64
#  12  mnth_3        219 non-null    int64
#  13  mnth_4        219 non-null    int64
#  14  mnth_5        219 non-null    int64
#  15  mnth_6        219 non-null    int64
#  16  mnth_7        219 non-null    int64
#  17  mnth_8        219 non-null    int64
#  18  mnth_9        219 non-null    int64
#  19  mnth_10       219 non-null    int64
#  20  mnth_11       219 non-null    int64
#  21  mnth_12       219 non-null    int64
#  22  weekday_1     219 non-null    int64
#  23  weekday_2     219 non-null    int64
#  24  weekday_3     219 non-null    int64
#  25  weekday_4     219 non-null    int64
#  26  weekday_5     219 non-null    int64
#  27  weekday_6     219 non-null    int64
#  28  weathersit_2  219 non-null    int64
#  29  weathersit_3  219 non-null    int64
# dtypes: int64(30)
# memory usage: 53.0 KB

# %%
df_test.shape
# Out:
# (219, 30)

# %% [markdown]
# **EDA**

# %% [markdown]
# **Visualising Numeric Variables**

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 510 entries, 483 to 366
# Data columns (total 30 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   yr            510 non-null    int64
#  1   holiday       510 non-null    int64
#  2   workingday    510 non-null    int64
#  3   temp          510 non-null    int64
#  4   atemp         510 non-null    int64
#  5   hum           510 non-null    int64
#  6   windspeed     510 non-null    int64
#  7   cnt           510 non-null    int64
#  8   season_2      510 non-null    int64
#  9   season_3      510 non-null    int64
#  10  season_4      510 non-null    int64
#  11  mnth_2        510 non-null    int64
#  12  mnth_3        510 non-null    int64
#  13  mnth_4        510 non-null    int64
#  14  mnth_5        510 non-null    int64
#  15  mnth_6        510 non-null    int64
#  16  mnth_7        510 non-null    int64
#  17  mnth_8        510 non-null    int64
#  18  mnth_9        510 non-null    int64
#  19  mnth_10       510 non-null    int64
#  20  mnth_11       510 non-null    int64
#  21  mnth_12       510 non-null    int64
#  22  weekday_1     510 non-null    int64
#  23  weekday_2     510 non-null    int64
#  24  weekday_3     510 non-null    int64
#  25  weekday_4     510 non-null    int64
#  26  weekday_5     510 non-null    int64
#  27  weekday_6     510 non-null    int64
#  28  weathersit_2  510 non-null    int64
#  29  weathersit_3  510 non-null    int64
# dtypes: int64(30)
# memory usage: 123.5 KB

# %%
df_train.columns
# Out:
# Index(['yr', 'holiday', 'workingday', 'temp', 'atemp', 'hum', 'windspeed',
#        'cnt', 'season_2', 'season_3', 'season_4', 'mnth_2', 'mnth_3', 'mnth_4',
#        'mnth_5', 'mnth_6', 'mnth_7', 'mnth_8', 'mnth_9', 'mnth_10', 'mnth_11',
#        'mnth_12', 'weekday_1', 'weekday_2', 'weekday_3', 'weekday_4',
#        'weekday_5', 'weekday_6', 'weathersit_2', 'weathersit_3'],
#       dtype='object')

# %%
# Create a new dataframe of only numeric variables:

bike_num=df_train[[ 'temp', 'atemp', 'hum', 'windspeed','cnt']]

sns.pairplot(bike_num, diag_kind='kde')
plt.show()

# %% [markdown]
#  #### Insights
#  The above Pair-Plot tells us that there is a LINEAR RELATION between 'temp','atemp' and 'cnt'

# %% [markdown]
# **Visualising Categorical Variables**

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 510 entries, 483 to 366
# Data columns (total 30 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   yr            510 non-null    int64
#  1   holiday       510 non-null    int64
#  2   workingday    510 non-null    int64
#  3   temp          510 non-null    int64
#  4   atemp         510 non-null    int64
#  5   hum           510 non-null    int64
#  6   windspeed     510 non-null    int64
#  7   cnt           510 non-null    int64
#  8   season_2      510 non-null    int64
#  9   season_3      510 non-null    int64
#  10  season_4      510 non-null    int64
#  11  mnth_2        510 non-null    int64
#  12  mnth_3        510 non-null    int64
#  13  mnth_4        510 non-null    int64
#  14  mnth_5        510 non-null    int64
#  15  mnth_6        510 non-null    int64
#  16  mnth_7        510 non-null    int64
#  17  mnth_8        510 non-null    int64
#  18  mnth_9        510 non-null    int64
#  19  mnth_10       510 non-null    int64
#  20  mnth_11       510 non-null    int64
#  21  mnth_12       510 non-null    int64
#  22  weekday_1     510 non-null    int64
#  23  weekday_2     510 non-null    int64
#  24  weekday_3     510 non-null    int64
#  25  weekday_4     510 non-null    int64
#  26  weekday_5     510 non-null    int64
#  27  weekday_6     510 non-null    int64
#  28  weathersit_2  510 non-null    int64
#  29  weathersit_3  510 non-null    int64
# dtypes: int64(30)
# memory usage: 123.5 KB

# %%
# Build boxplot of all categorical variables (before creating dummies) againt the target variable 'cnt'
# to see how each of the predictor variable stackup against the target variable.

plt.figure(figsize=(25, 10))
plt.subplot(2,3,1)
sns.boxplot(x = 'season', y = 'cnt', data = bike)
plt.subplot(2,3,2)
sns.boxplot(x = 'mnth', y = 'cnt', data = bike)
plt.subplot(2,3,3)
sns.boxplot(x = 'weathersit', y = 'cnt', data = bike)
plt.subplot(2,3,4)
sns.boxplot(x = 'holiday', y = 'cnt', data = bike)
plt.subplot(2,3,5)
sns.boxplot(x = 'weekday', y = 'cnt', data = bike)
plt.subplot(2,3,6)
sns.boxplot(x = 'workingday', y = 'cnt', data = bike)
plt.show()

# %%
# Let's check the correlation coefficients to see which variables are highly correlated. Note:
# here we are considering only those variables (dataframe: bike_new) that were chosen for analysis

plt.figure(figsize = (25,20))
sns.heatmap(bike_new.corr(), annot = True, cmap="RdBu")
plt.show()

# %% [markdown]
# #### Insights:
# The heatmap clearly shows which all variable are multicollinear in nature, and which variable have high collinearity with the target variable.

# %% [markdown]
# **Rescaling**

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
# Checking the values before scaling
df_train.head()
# Out:
#      yr  holiday  workingday  temp  atemp  hum  windspeed   cnt  season_2  \
# 483   1        0           0    18     22   58          7  6304         1
# 650   1        0           0    16     19   49          9  7109         0
# 212   0        0           1    31     35   55         10  4266         0
# 714   1        0           0    14     18   83          6  3786         0
# 8     0        0           0     5      5   43         24   822         0
#
#      season_3  ...  mnth_11  mnth_12  weekday_1  weekday_2  weekday_3  \
# 483         0  ...        0        0          0          0          0
# 650         0  ...        0        0          0          0          0
# 212         1  ...        0        0          1          0          0
# 714         0  ...        0        1          0          0          0
# 8           0  ...        0        0          0          0          0
#
#      weekday_4  weekday_5  weekday_6  weathersit_2  weathersit_3
# 483          0          0          0             0             0
# 650          0          0          1             0             0
# 212          0          0          0             0             0
# 714          0          0          0             1             0
# 8            0          0          0             0             0
#
# [5 rows x 30 columns]

# %%
df_train.columns
# Out:
# Index(['yr', 'holiday', 'workingday', 'temp', 'atemp', 'hum', 'windspeed',
#        'cnt', 'season_2', 'season_3', 'season_4', 'mnth_2', 'mnth_3', 'mnth_4',
#        'mnth_5', 'mnth_6', 'mnth_7', 'mnth_8', 'mnth_9', 'mnth_10', 'mnth_11',
#        'mnth_12', 'weekday_1', 'weekday_2', 'weekday_3', 'weekday_4',
#        'weekday_5', 'weekday_6', 'weathersit_2', 'weathersit_3'],
#       dtype='object')

# %%
# Apply scaler() to all the numeric variables

num_vars = ['temp', 'atemp', 'hum', 'windspeed','cnt']

df_train[num_vars] = scaler.fit_transform(df_train[num_vars])

# %%
# Checking values after scaling
df_train.head()
# Out:
#      yr  holiday  workingday      temp     atemp       hum  windspeed  \
# 483   1        0           0  0.484848  0.487179  0.604167   0.181818
# 650   1        0           0  0.424242  0.410256  0.510417   0.242424
# 212   0        0           1  0.878788  0.820513  0.572917   0.272727
# 714   1        0           0  0.363636  0.384615  0.864583   0.151515
# 8     0        0           0  0.090909  0.051282  0.447917   0.696970
#
#           cnt  season_2  season_3  ...  mnth_11  mnth_12  weekday_1  \
# 483  0.722734         1         0  ...        0        0          0
# 650  0.815347         0         0  ...        0        0          0
# 212  0.488265         0         1  ...        0        0          1
# 714  0.433042         0         0  ...        0        1          0
# 8    0.092039         0         0  ...        0        0          0
#
#      weekday_2  weekday_3  weekday_4  weekday_5  weekday_6  weathersit_2  \
# 483          0          0          0          0          0             0
# 650          0          0          0          0          1             0
# 212          0          0          0          0          0             0
# 714          0          0          0          0          0             1
# 8            0          0          0          0          0             0
#
#      weathersit_3
# 483             0
# 650             0
# 212             0
# 714             0
# 8               0
#
# [5 rows x 30 columns]

# %%
df_train.describe()
# Out:
#                yr     holiday  workingday        temp       atemp         hum  \
# count  510.000000  510.000000  510.000000  510.000000  510.000000  510.000000
# mean     0.501961    0.023529    0.682353    0.536720    0.515184    0.644036
# std      0.500487    0.151726    0.466018    0.227072    0.209016    0.149901
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.333333    0.333333    0.531250
# 50%      1.000000    0.000000    1.000000    0.545455    0.525641    0.645833
# 75%      1.000000    0.000000    1.000000    0.727273    0.692308    0.750000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#         windspeed         cnt    season_2    season_3  ...     mnth_11  \
# count  510.000000  510.000000  510.000000  510.000000  ...  510.000000
# mean     0.341058    0.515144    0.247059    0.262745  ...    0.086275
# std      0.157847    0.224281    0.431725    0.440557  ...    0.281045
# min      0.000000    0.000000    0.000000    0.000000  ...    0.000000
# 25%      0.242424    0.359468    0.000000    0.000000  ...    0.000000
# 50%      0.333333    0.516337    0.000000    0.000000  ...    0.000000
# 75%      0.424242    0.685861    0.000000    1.000000  ...    0.000000
# max      1.000000    1.000000    1.000000    1.000000  ...    1.000000
#
#           mnth_12   weekday_1   weekday_2   weekday_3   weekday_4   weekday_5  \
# count  510.000000  510.000000  510.000000  510.000000  510.000000  510.000000
# mean     0.076471    0.139216    0.141176    0.150980    0.129412    0.145098
# std      0.266010    0.346511    0.348545    0.358381    0.335985    0.352545
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#         weekday_6  weathersit_2  weathersit_3
# count  510.000000    510.000000    510.000000
# mean     0.150980      0.341176      0.025490
# std      0.358381      0.474570      0.157763
# min      0.000000      0.000000      0.000000
# 25%      0.000000      0.000000      0.000000
# 50%      0.000000      0.000000      0.000000
# 75%      0.000000      1.000000      0.000000
# max      1.000000      1.000000      1.000000
#
# [8 rows x 30 columns]

# %% [markdown]
# **Model Building(Linear)**

# %% [markdown]
# ##### Dividing into X and Y sets for the model building

# %%
y_train = df_train.pop('cnt')
X_train = df_train

# %% [markdown]
#  **Model Building using 'Stats.**

# %% [markdown]
# **RFE**
#  Recursive feature elimination:
#
#  Using the LinearRegression function from SciKit Learn for its compatibility with RFE (which is a utility from sklearn)

# %%
# Importing RFE and LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# %%
# Create the Linear Regression model
lm = LinearRegression()

# Run RFE to select 15 features
rfe = RFE(estimator=lm, n_features_to_select=15)  # Correct argument usage
rfe = rfe.fit(X_train, y_train)

# %%
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('yr', True, 1),
#  ('holiday', False, 13),
#  ('workingday', True, 1),
#  ('temp', True, 1),
#  ('atemp', True, 1),
#  ('hum', True, 1),
#  ('windspeed', True, 1),
#  ('season_2', True, 1),
#  ('season_3', True, 1),
#  ('season_4', True, 1),
#  ('mnth_2', False, 7),
#  ('mnth_3', True, 1),
#  ('mnth_4', False, 4),
#  ('mnth_5', False, 2),
#  ('mnth_6', False, 3),
#  ('mnth_7', False, 14),
#  ('mnth_8', False, 5),
#  ('mnth_9', True, 1),
#  ('mnth_10', True, 1),
#  ('mnth_11', False, 8),
#  ('mnth_12', False, 9),
#  ('weekday_1', False, 6),
#  ('weekday_2', False, 15),
#  ('weekday_3', False, 11),
#  ('weekday_4', False, 12),
#  ('weekday_5', False, 10),
#  ('weekday_6', True, 1),
#  ('weathersit_2', True, 1),
#  ('weathersit_3', True, 1)]

# %%
col = X_train.columns[rfe.support_]
col
# Out:
# Index(['yr', 'workingday', 'temp', 'atemp', 'hum', 'windspeed', 'season_2',
#        'season_3', 'season_4', 'mnth_3', 'mnth_9', 'mnth_10', 'weekday_6',
#        'weathersit_2', 'weathersit_3'],
#       dtype='object')

# %%
X_train.columns[~rfe.support_]
# Out:
# Index(['holiday', 'mnth_2', 'mnth_4', 'mnth_5', 'mnth_6', 'mnth_7', 'mnth_8',
#        'mnth_11', 'mnth_12', 'weekday_1', 'weekday_2', 'weekday_3',
#        'weekday_4', 'weekday_5'],
#       dtype='object')

# %%
# Creating X_test dataframe with RFE selected variables
X_train_rfe = X_train[col]

# %% [markdown]
# **Model 1**
#
# **VIF Check**

# %%
# Check for the VIF values of the feature variables.
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train_rfe.columns
vif['VIF'] = [variance_inflation_factor(X_train_rfe.values, i) for i in range(X_train_rfe.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#         Features     VIF
# 2           temp  337.86
# 3          atemp  331.18
# 4            hum   17.70
# 7       season_3    7.02
# 5      windspeed    4.63
# 1     workingday    4.61
# 6       season_2    3.52
# 8       season_4    3.02
# 13  weathersit_2    2.15
# 0             yr    2.02
# 12     weekday_6    1.80
# 11       mnth_10    1.66
# 10        mnth_9    1.28
# 9         mnth_3    1.20
# 14  weathersit_3    1.18

# %%
import statsmodels.api as sm

# Add a constant
X_train_lm1 = sm.add_constant(X_train_rfe)

# Create a first fitted model
lr1 = sm.OLS(y_train, X_train_lm1).fit()

# %%
# Check the parameters obtained

lr1.params
# Out:
# const           0.194649
# yr              0.229158
# workingday      0.040942
# temp            0.334959
# atemp           0.161194
# hum            -0.180327
# windspeed      -0.185351
# season_2        0.132393
# season_3        0.085301
# season_4        0.153411
# mnth_3          0.048364
# mnth_9          0.099637
# mnth_10         0.055748
# weekday_6       0.054833
# weathersit_2   -0.047276
# weathersit_3   -0.271080
# dtype: float64

# %%
# Print a summary of the linear regression model obtained
print(lr1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.841
# Model:                            OLS   Adj. R-squared:                  0.836
# Method:                 Least Squares   F-statistic:                     174.1
# Date:                Sun, 29 Dec 2024   Prob (F-statistic):          4.09e-186
# Time:                        10:48:37   Log-Likelihood:                 508.05
# No. Observations:                 510   AIC:                            -984.1
# Df Residuals:                     494   BIC:                            -916.4
# Df Model:                          15
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.1946      0.030      6.506      0.000       0.136       0.253
# yr               0.2292      0.008     28.005      0.000       0.213       0.245
# workingday       0.0409      0.011      3.709      0.000       0.019       0.063
# temp             0.3350      0.127      2.632      0.009       0.085       0.585
# atemp            0.1612      0.133      1.213      0.226      -0.100       0.422
# hum             -0.1803      0.037     -4.818      0.000      -0.254      -0.107
# windspeed       -0.1854      0.029     -6.494      0.000      -0.241      -0.129
# season_2         0.1324      0.015      8.714      0.000       0.103       0.162
# season_3         0.0853      0.021      4.102      0.000       0.044       0.126
# season_4         0.1534      0.014     10.733      0.000       0.125       0.181
# mnth_3           0.0484      0.016      3.028      0.003       0.017       0.080
# mnth_9           0.0996      0.016      6.265      0.000       0.068       0.131
# mnth_10          0.0557      0.018      3.118      0.002       0.021       0.091
# weekday_6        0.0548      0.014      3.823      0.000       0.027       0.083
# weathersit_2    -0.0473      0.011     -4.427      0.000      -0.068      -0.026
# weathersit_3    -0.2711      0.028     -9.515      0.000      -0.327      -0.215
# ==============================================================================
# Omnibus:                       93.932   Durbin-Watson:                   2.034
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              224.841
# Skew:                          -0.946   Prob(JB):                     1.50e-49
# Kurtosis:                       5.647   Cond. No.                         81.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### Removing the variable 'atemp' based on its High p-value & High VIF

# %%
X_train_new = X_train_rfe.drop(["atemp"], axis = 1)

# %% [markdown]
# **VIF Check**

# %%
# Check for the VIF values of the feature variables.
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train_new.columns
vif['VIF'] = [variance_inflation_factor(X_train_new.values, i) for i in range(X_train_new.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#         Features    VIF
# 2           temp  22.87
# 3            hum  17.09
# 6       season_3   6.96
# 1     workingday   4.59
# 4      windspeed   4.53
# 5       season_2   3.52
# 7       season_4   3.01
# 12  weathersit_2   2.14
# 0             yr   2.02
# 11     weekday_6   1.79
# 10       mnth_10   1.66
# 9         mnth_9   1.28
# 8         mnth_3   1.20
# 13  weathersit_3   1.17

# %%
# Add a constant
X_train_lm2 = sm.add_constant(X_train_new)

# Create a first fitted model
lr2 = sm.OLS(y_train, X_train_lm2).fit()

# %%
# Check the parameters obtained

lr2.params
# Out:
# const           0.199599
# yr              0.229092
# workingday      0.041153
# temp            0.483856
# hum            -0.179155
# windspeed      -0.192068
# season_2        0.132987
# season_3        0.083052
# season_4        0.153893
# mnth_3          0.048835
# mnth_9          0.099559
# mnth_10         0.056085
# weekday_6       0.055204
# weathersit_2   -0.047735
# weathersit_3   -0.272160
# dtype: float64

# %%
# Print a summary of the linear regression model obtained
print(lr2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.840
# Model:                            OLS   Adj. R-squared:                  0.836
# Method:                 Least Squares   F-statistic:                     186.3
# Date:                Sun, 29 Dec 2024   Prob (F-statistic):          6.12e-187
# Time:                        10:48:57   Log-Likelihood:                 507.29
# No. Observations:                 510   AIC:                            -984.6
# Df Residuals:                     495   BIC:                            -921.1
# Df Model:                          14
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.1996      0.030      6.731      0.000       0.141       0.258
# yr               0.2291      0.008     27.984      0.000       0.213       0.245
# workingday       0.0412      0.011      3.727      0.000       0.019       0.063
# temp             0.4839      0.034     14.384      0.000       0.418       0.550
# hum             -0.1792      0.037     -4.786      0.000      -0.253      -0.106
# windspeed       -0.1921      0.028     -6.856      0.000      -0.247      -0.137
# season_2         0.1330      0.015      8.753      0.000       0.103       0.163
# season_3         0.0831      0.021      4.008      0.000       0.042       0.124
# season_4         0.1539      0.014     10.766      0.000       0.126       0.182
# mnth_3           0.0488      0.016      3.057      0.002       0.017       0.080
# mnth_9           0.0996      0.016      6.257      0.000       0.068       0.131
# mnth_10          0.0561      0.018      3.136      0.002       0.021       0.091
# weekday_6        0.0552      0.014      3.848      0.000       0.027       0.083
# weathersit_2    -0.0477      0.011     -4.470      0.000      -0.069      -0.027
# weathersit_3    -0.2722      0.028     -9.553      0.000      -0.328      -0.216
# ==============================================================================
# Omnibus:                       93.537   Durbin-Watson:                   2.036
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              222.992
# Skew:                          -0.943   Prob(JB):                     3.78e-49
# Kurtosis:                       5.633   Cond. No.                         21.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Model 3
# Removing the variable 'hum' based on its Very High 'VIF' value.
# Even though the VIF of hum is second highest, we decided to drop 'hum' and not 'temp' based on general knowledge that temperature can be an important factor for a business like bike rentals, and wanted to retain 'temp'.

# %%
X_train_new = X_train_new.drop(["hum"], axis = 1)

# %% [markdown]
# **VIF Check**

# %%
# Check for the VIF values of the feature variables.
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train_new.columns
vif['VIF'] = [variance_inflation_factor(X_train_new.values, i) for i in range(X_train_new.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#         Features    VIF
# 2           temp  16.61
# 5       season_3   6.71
# 3      windspeed   4.27
# 1     workingday   4.09
# 4       season_2   3.50
# 6       season_4   2.90
# 0             yr   2.02
# 9        mnth_10   1.66
# 10     weekday_6   1.66
# 11  weathersit_2   1.54
# 8         mnth_9   1.27
# 7         mnth_3   1.20
# 12  weathersit_3   1.08

# %%
# Add a constant
X_train_lm3 = sm.add_constant(X_train_new)

# Create a first fitted model
lr3 = sm.OLS(y_train, X_train_lm3).fit()

# %%
lr3.params
# Out:
# const           0.094482
# yr              0.233463
# workingday      0.042859
# temp            0.451195
# windspeed      -0.152105
# season_2        0.134464
# season_3        0.092054
# season_4        0.150262
# mnth_3          0.056696
# mnth_9          0.091037
# mnth_10         0.054955
# weekday_6       0.055890
# weathersit_2   -0.077469
# weathersit_3   -0.325346
# dtype: float64

# %%
# Print a summary of the linear regression model obtained
print(lr3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.833
# Model:                            OLS   Adj. R-squared:                  0.829
# Method:                 Least Squares   F-statistic:                     190.4
# Date:                Sun, 29 Dec 2024   Prob (F-statistic):          3.00e-183
# Time:                        10:49:17   Log-Likelihood:                 495.76
# No. Observations:                 510   AIC:                            -963.5
# Df Residuals:                     496   BIC:                            -904.2
# Df Model:                          13
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.0945      0.020      4.641      0.000       0.054       0.134
# yr               0.2335      0.008     28.084      0.000       0.217       0.250
# workingday       0.0429      0.011      3.801      0.000       0.021       0.065
# temp             0.4512      0.034     13.405      0.000       0.385       0.517
# windspeed       -0.1521      0.027     -5.566      0.000      -0.206      -0.098
# season_2         0.1345      0.016      8.663      0.000       0.104       0.165
# season_3         0.0921      0.021      4.365      0.000       0.051       0.133
# season_4         0.1503      0.015     10.302      0.000       0.122       0.179
# mnth_3           0.0567      0.016      3.491      0.001       0.025       0.089
# mnth_9           0.0910      0.016      5.634      0.000       0.059       0.123
# mnth_10          0.0550      0.018      3.007      0.003       0.019       0.091
# weekday_6        0.0559      0.015      3.813      0.000       0.027       0.085
# weathersit_2    -0.0775      0.009     -8.730      0.000      -0.095      -0.060
# weathersit_3    -0.3253      0.027    -12.137      0.000      -0.378      -0.273
# ==============================================================================
# Omnibus:                       88.938   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              209.874
# Skew:                          -0.903   Prob(JB):                     2.67e-46
# Kurtosis:                       5.572   Cond. No.                         16.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
#  ### Model 4

# %%
X_train_new = X_train_new.drop(["season_3"], axis = 1)

# %% [markdown]
# **VIF Check**

# %%
# Check for the VIF values of the feature variables.
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train_new.columns
vif['VIF'] = [variance_inflation_factor(X_train_new.values, i) for i in range(X_train_new.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#         Features   VIF
# 2           temp  4.90
# 3      windspeed  4.15
# 1     workingday  4.06
# 0             yr  2.01
# 5       season_4  1.97
# 9      weekday_6  1.66
# 8        mnth_10  1.63
# 4       season_2  1.56
# 10  weathersit_2  1.54
# 7         mnth_9  1.23
# 6         mnth_3  1.15
# 11  weathersit_3  1.08

# %%
# Add a constant
X_train_lm4 = sm.add_constant(X_train_new)

# Create a first fitted model
lr4 = sm.OLS(y_train, X_train_lm4).fit()

# %%
# Check the parameters obtained

lr4.params
# Out:
# const           0.079022
# yr              0.231624
# workingday      0.042784
# temp            0.568270
# windspeed      -0.156402
# season_2        0.084025
# season_4        0.118053
# mnth_3          0.045207
# mnth_9          0.103151
# mnth_10         0.043320
# weekday_6       0.057568
# weathersit_2   -0.077721
# weathersit_3   -0.317644
# dtype: float64

# %%
# Print a summary of the linear regression model obtained
print(lr4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.827
# Model:                            OLS   Adj. R-squared:                  0.823
# Method:                 Least Squares   F-statistic:                     197.6
# Date:                Sun, 29 Dec 2024   Prob (F-statistic):          2.30e-180
# Time:                        10:49:35   Log-Likelihood:                 486.14
# No. Observations:                 510   AIC:                            -946.3
# Df Residuals:                     497   BIC:                            -891.2
# Df Model:                          12
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.0790      0.020      3.872      0.000       0.039       0.119
# yr               0.2316      0.008     27.405      0.000       0.215       0.248
# workingday       0.0428      0.011      3.727      0.000       0.020       0.065
# temp             0.5683      0.021     27.446      0.000       0.528       0.609
# windspeed       -0.1564      0.028     -5.626      0.000      -0.211      -0.102
# season_2         0.0840      0.011      7.964      0.000       0.063       0.105
# season_4         0.1181      0.013      9.216      0.000       0.093       0.143
# mnth_3           0.0452      0.016      2.771      0.006       0.013       0.077
# mnth_9           0.1032      0.016      6.366      0.000       0.071       0.135
# mnth_10          0.0433      0.018      2.354      0.019       0.007       0.079
# weekday_6        0.0576      0.015      3.859      0.000       0.028       0.087
# weathersit_2    -0.0777      0.009     -8.603      0.000      -0.095      -0.060
# weathersit_3    -0.3176      0.027    -11.666      0.000      -0.371      -0.264
# ==============================================================================
# Omnibus:                       71.633   Durbin-Watson:                   2.043
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              142.678
# Skew:                          -0.797   Prob(JB):                     1.04e-31
# Kurtosis:                       5.043   Cond. No.                         12.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Insights
# This model looks good, as there seems to be VERY LOW Multicollinearity between the predictors and the p-values for all the predictors seems to be significant. For now, we will consider this as our final model (unless the Test data metrics are not significantly close to this number).

# %% [markdown]
# Residual Analysis Of Training Data

# %%
y_train_pred = lr4.predict(X_train_lm4)

# %%
res = y_train-y_train_pred
# Plot the histogram of the error terms
fig = plt.figure()
sns.distplot((res), bins = 20)
fig.suptitle('Error Terms', fontsize = 20)                  # Plot heading
plt.xlabel('Errors', fontsize = 18)                         # X-label
# Out:
# Text(0.5, 0, 'Errors')

# %% [markdown]
# Insights
# From the above histogram, we could see that the Residuals are normally distributed. Hence our assumption for Linear Regression is valid

# %% [markdown]
# **MAKING MODEL PREDICTION**
# Now that we have fitted the model and checked the assumptions, it's time to go ahead and make predictions using the final model (lr4)

# %% [markdown]
# Applying the scaling on the test sets

# %%
# Apply scaler() to all numeric variables in test dataset. Note: we will only use scaler.transform,
# as we want to use the metrics that the model learned from the training data to be applied on the test data.
# In other words, we want to prevent the information leak from train to test dataset.

num_vars = ['temp', 'atemp', 'hum', 'windspeed','cnt']

df_test[num_vars] = scaler.transform(df_test[num_vars])

# %%
df_test.head()
# Out:
#      yr  holiday  workingday      temp     atemp       hum  windspeed  \
# 22    0        0           0  0.030303  0.025641  0.447917   0.454545
# 468   1        0           0  0.545455  0.538462  0.520833   0.333333
# 553   1        0           0  0.939394  0.923077  0.593750   0.212121
# 504   1        0           0  0.696970  0.666667  0.552083   0.484848
# 353   0        0           1  0.393939  0.410256  0.614583   0.090909
#
#           cnt  season_2  season_3  ...  mnth_11  mnth_12  weekday_1  \
# 22   0.110907         0         0  ...        0        0          0
# 468  0.855729         1         0  ...        0        0          0
# 553  0.534975         0         1  ...        0        0          0
# 504  0.817648         1         0  ...        0        0          0
# 353  0.428900         0         0  ...        0        1          0
#
#      weekday_2  weekday_3  weekday_4  weekday_5  weekday_6  weathersit_2  \
# 22           0          0          0          0          0             0
# 468          0          0          0          0          1             0
# 553          0          0          0          0          0             0
# 504          0          0          0          0          0             0
# 353          1          0          0          0          0             1
#
#      weathersit_3
# 22              0
# 468             0
# 553             0
# 504             0
# 353             0
#
# [5 rows x 30 columns]

# %%
df_test.describe()
# Out:
#                yr     holiday  workingday        temp       atemp         hum  \
# count  219.000000  219.000000  219.000000  219.000000  219.000000  219.000000
# mean     0.493151    0.041096    0.684932    0.547115    0.526168    0.659532
# std      0.501098    0.198967    0.465607    0.229218    0.210531    0.144240
# min      0.000000    0.000000    0.000000    0.030303    0.025641    0.302083
# 25%      0.000000    0.000000    0.000000    0.363636    0.346154    0.552083
# 50%      0.000000    0.000000    1.000000    0.545455    0.538462    0.656250
# 75%      1.000000    0.000000    1.000000    0.757576    0.705128    0.760417
# max      1.000000    1.000000    1.000000    0.969697    0.974359    1.010417
#
#         windspeed         cnt    season_2    season_3  ...     mnth_11  \
# count  219.000000  219.000000  219.000000  219.000000  ...  219.000000
# mean     0.341497    0.518889    0.264840    0.246575  ...    0.073059
# std      0.156938    0.219953    0.442259    0.432005  ...    0.260830
# min      0.060606    0.055683    0.000000    0.000000  ...    0.000000
# 25%      0.242424    0.364703    0.000000    0.000000  ...    0.000000
# 50%      0.333333    0.525771    0.000000    0.000000  ...    0.000000
# 75%      0.424242    0.676887    1.000000    0.000000  ...    0.000000
# max      0.818182    0.963300    1.000000    1.000000  ...    1.000000
#
#           mnth_12   weekday_1   weekday_2   weekday_3   weekday_4   weekday_5  \
# count  219.000000  219.000000  219.000000  219.000000  219.000000  219.000000
# mean     0.105023    0.155251    0.146119    0.118721    0.173516    0.132420
# std      0.307285    0.362974    0.354034    0.324202    0.379560    0.339723
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#         weekday_6  weathersit_2  weathersit_3
# count  219.000000    219.000000    219.000000
# mean     0.127854      0.324201      0.036530
# std      0.334692      0.469148      0.188034
# min      0.000000      0.000000      0.000000
# 25%      0.000000      0.000000      0.000000
# 50%      0.000000      0.000000      0.000000
# 75%      0.000000      1.000000      0.000000
# max      1.000000      1.000000      1.000000
#
# [8 rows x 30 columns]

# %% [markdown]
# Dividing into X_test and y_test

# %%
y_test = df_test.pop('cnt')
X_test = df_test
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 219 entries, 22 to 313
# Data columns (total 29 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   yr            219 non-null    int64
#  1   holiday       219 non-null    int64
#  2   workingday    219 non-null    int64
#  3   temp          219 non-null    float64
#  4   atemp         219 non-null    float64
#  5   hum           219 non-null    float64
#  6   windspeed     219 non-null    float64
#  7   season_2      219 non-null    int64
#  8   season_3      219 non-null    int64
#  9   season_4      219 non-null    int64
#  10  mnth_2        219 non-null    int64
#  11  mnth_3        219 non-null    int64
#  12  mnth_4        219 non-null    int64
#  13  mnth_5        219 non-null    int64
#  14  mnth_6        219 non-null    int64
#  15  mnth_7        219 non-null    int64
#  16  mnth_8        219 non-null    int64
#  17  mnth_9        219 non-null    int64
#  18  mnth_10       219 non-null    int64
#  19  mnth_11       219 non-null    int64
#  20  mnth_12       219 non-null    int64
#  21  weekday_1     219 non-null    int64
#  22  weekday_2     219 non-null    int64
#  23  weekday_3     219 non-null    int64
#  24  weekday_4     219 non-null    int64
#  25  weekday_5     219 non-null    int64
#  26  weekday_6     219 non-null    int64
#  27  weathersit_2  219 non-null    int64
#  28  weathersit_3  219 non-null    int64
# dtypes: float64(4), int64(25)
# memory usage: 51.3 KB

# %%
#Selecting the variables that were part of final model.
col1=X_train_new.columns
X_test=X_test[col1]
# Adding constant variable to test dataframe
X_test_lm4 = sm.add_constant(X_test)
X_test_lm4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 219 entries, 22 to 313
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   const         219 non-null    float64
#  1   yr            219 non-null    int64
#  2   workingday    219 non-null    int64
#  3   temp          219 non-null    float64
#  4   windspeed     219 non-null    float64
#  5   season_2      219 non-null    int64
#  6   season_4      219 non-null    int64
#  7   mnth_3        219 non-null    int64
#  8   mnth_9        219 non-null    int64
#  9   mnth_10       219 non-null    int64
#  10  weekday_6     219 non-null    int64
#  11  weathersit_2  219 non-null    int64
#  12  weathersit_3  219 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 24.0 KB

# %%
# Making predictions using the final model (lr6)

y_pred = lr4.predict(X_test_lm4)

# %% [markdown]
# Model Evaluation

# %%
# Plotting y_test and y_pred to understand the spread

fig = plt.figure()
plt.scatter(y_test, y_pred, alpha=.5)
fig.suptitle('y_test vs y_pred', fontsize = 20)              # Plot heading
plt.xlabel('y_test', fontsize = 18)                          # X-label
plt.ylabel('y_pred', fontsize = 16)
plt.show()

# %% [markdown]
# R² Value for TEST

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.8176645515101271

# %% [markdown]
# ** Final Result Comparison**
# Train R²  :0.827
# Train Adjusted R²  :0.823
# Test R²  :0.8176
# Test Adjusted R²  :0.812
# This seems to be a really good model that can very well 'Generalize' various datasets.

# %% [markdown]
# **Conclusion**
# As per our final Model, the top 3 predictor variables that influences the bike booking are:
#
#
#
# 1.   Temperature (temp) - A coefficient value of ‘0.5683’ indicated that a unit increase in temp variable increases the bike hire numbers by 0.5683 units.
# 2.   Weather Situation 3 (weathersit_3) - A coefficient value of ‘-0.3176’ indicated that, w.r.t Weathersit1, a unit increase in Weathersit3 variable decreases the bike hire numbers by 0.3176 units.
# 3. Year (yr) - A coefficient value of ‘0.2316’ indicated that a unit increase in yr variable increases the bike hire numbers by 0.2316 units.
